# %%
import pandas as pd
import numpy as np
import os
import re
import ast

# %%
DATA_PATH = '../data'
FILENAME_TAXO = 'simple_taxo.csv'
FILENAME_RULES = '2020-01-09 Set aanvullende controleregels Solvency II_tcm46-386880.xlsx'

# %% [markdown]
# ## Read simplified taxonomy of Solvency 2

# %%
df_taxo = pd.read_csv(os.path.join(DATA_PATH, FILENAME_TAXO), encoding='latin-1')
df_taxo = df_taxo.drop("Unnamed: 0", axis = 1)

# %%
df_taxo.head(5)
# Out:
#                    datapoint       template    row column   dtype
# 0  S.01.01.01.01,r0010,c0010  S.01.01.01.01  r0010  c0010  object
# 1  S.01.01.01.01,r0020,c0010  S.01.01.01.01  r0020  c0010  object
# 2  S.01.01.01.01,r0030,c0010  S.01.01.01.01  r0030  c0010  object
# 3  S.01.01.01.01,r0040,c0010  S.01.01.01.01  r0040  c0010  object
# 4  S.01.01.01.01,r0060,c0010  S.01.01.01.01  r0060  c0010  object

# %% [markdown]
# ## Construct test Solvency 2 instance (put here your own data)

# %%
taxo_datatypes = dict()
for row in df_taxo.index:
    taxo_datatypes[df_taxo.loc[row, "datapoint"]] = df_taxo.loc[row, "dtype"]
    
unique_dp = list(df_taxo['datapoint'].unique())
data_dp = [[0 if taxo_datatypes[i]=='int64' else 0.0 if taxo_datatypes[i]=='float64' else "text" for i in unique_dp]]

df = pd.DataFrame(columns = unique_dp, data = data_dp)

# %% [markdown]
# ## Read DNBs Additional Validation Rules

# %%
df_vr = pd.read_excel(os.path.join(DATA_PATH, FILENAME_RULES), header = 1)
df_vr = df_vr.set_index('ControleRegelCode')
df_vr = df_vr.drop('S.28.01_129', axis = 0)
df_vr.fillna("", inplace = True)

# %%
preprocess("lksdfklsd f ) sdSd")
# Out:
# 'lksdfklsd f) sdSd'

# %%
def add_brackets(s):
    """Add brackets around expressions with & and | (this is not consistent in EVA2)
    TODO: should not apply is AND or OR is in string text
    """
    item = re.search(r'(.*)\s*([&|\||>|<|!=|<=|>=|==])\s*(.*)', s)
    if item is not None:
        if item[2].strip() in ['&', '|']:
            return '('+ add_brackets(item[1]) + ') ' + item[2].strip() + ' (' + add_brackets(item[3]) + ')'
        else:
            return add_brackets(item[1]) + item[2].strip() + add_brackets(item[3])
    else:
        return s.strip()
    
def preprocess(s):
    """Transform EVA2 code to Python Pandas code"""
    res = s
    res = res.replace("=" , "==")
    res = res.replace(">==" , ">=")
    res = res.replace("<==" , "<=")
    res = res.replace("<>", "!=")
    res = res.replace("< >", "!=") # the space between < and > should be deleted in EVA2
    res = res.replace('"', "'")
    res = res.replace('OR', "|")
    res = res.replace('AND', "&")
    res = res.replace(" )", ")")
    res = res.replace(';', ",") # this should be corrected in EVA2
    return res

def transform_datapoints(s, columns):
    """Transform EVA2 datapoints to Python Pandas datapoints"""
    res = s
    not_found = []
    for item in re.findall(r'{(.*?)}', res):
        res = res.replace("{"+item+"}", "df['"+item+"']")
        if item not in list(columns):
            not_found.append(item)
    return res, not_found

def transform_conditional_expression(g):
    """Transform EVA2 conditional expression to Python Pandas code"""
    item = re.search(r'IF\s*(.*)\s*THEN\s*(.*)\s*', g)
    if item is not None:
        co_str = 'df[('+add_brackets(item[1])+') & ('+add_brackets(item[2])+")]"
        ex_str = 'df[('+add_brackets(item[1])+') & ~('+add_brackets(item[2])+")]"
    else:
        co_str = 'df[('+add_brackets(g)+')]'
        ex_str = 'df[~('+add_brackets(g)+')]'
    return co_str, ex_str

def evaluate_strings(co_str, ex_str):
    """Evaluate Python Pandas string for confirmation and exceptions"""
    try:
        co = len(eval(co_str, {'df': df, 'MAX': np.maximum, 'MIN': np.minimum, 'SUM': np.sum}))
        ex = len(eval(ex_str, {'df': df, 'MAX': np.maximum, 'MIN': np.minimum, 'SUM': np.sum}))
        return "Correctly parsed (#co=" + str(co)+", #ex="+str(ex)+")"
    except:
        return "Parse error: " + co_str
        
def get_all_datapoints(template, dim):
    """Get all rows or columns in the taxonomy given a template with column or row"""
    d = dim.lower()
    if 'r' in d:
        l = list(df_taxo[(df_taxo['template']==template) & (df_taxo['row']==dim)]['column'].values)
        if l != ['']:
            dp = [template + "," + d + "," + column for column in l]
        else:
            dp = [template + "," + d]
        return dp
    elif 'c' in d:
        l = list(df_taxo[(df_taxo['template']==template) & (df_taxo['column']==dim)]['row'].values)
        if l != ['']:
            dp = [template + "," + row + "," + d for row in l]
        else:
            dp = [template + "," + d]
        return dp

# %%
def evaluate_rules(df_data, df_rules, df_taxo):
    for row in df_rules.index:
        print("Rule " + row + ": ", end='')
        original = df_rules.loc[row, 'Formule']
        g = preprocess(original)
        g, not_found = transform_datapoints(g, df_data.columns)
        if not_found == []:
            # Simple expression with complete datapoints
            co_str, ex_str = transform_conditional_expression(g)
            print(evaluate_strings(co_str, ex_str))
        else:
            # Datapoints in expression should be expanded with the content of Rijen and Kolommen
#             to_select_rows = df_rules.loc[row, "Rijen"].replace("(", "").replace(")", "")
#             to_select_columns = df_rules.loc[row, "Kolommen"].replace("(", "").replace(")", "")
#             if (to_select_rows != "") and not('all' in to_select_rows.lower()):
#                 to_select_rows = ["r" + r if len(r)==4 else r for r in to_select_rows.split(";")]
# #               print(to_select_rows)
#             if (to_select_columns != "") and not('all' in to_select_columns.lower()): 
#                 to_select_columns = ["c" + r if len(r)==4 else r for r in to_select_columns.split(";")]
# #               print(to_select_columns)
            expansion = []
            for datapoint in not_found:
                template = datapoint[0:13]
                dim = datapoint[14:]
                l = get_all_datapoints(template, dim)
            print("Complex expression")
#                 if l is None:
#                     print("Datapoint string: " + str(datapoint))
#                 else:
#                     if len(l) == 0:
#                         print("Datapoint not found " + str(datapoint))
#                     else:
#                         expansion.append(l)
#             if expansion !=[]:
#                 print("Not yet implemented: expand possible ")
#                 for row in to_select_rows:
#                     a = datapoint[0:13] + "," + row + datapoint[13:19]
#                     if a in df_taxo['datapoint'].values:
#                         print(a + ": found")

# %%
evaluate_rules(df, df_vr, df_taxo)
# Out:
# Rule S.01.01_111: Correctly parsed (#co=0, #ex=0)
# Rule S.01.01_112: Correctly parsed (#co=0, #ex=0)
# Rule S.01.01_113: Correctly parsed (#co=1, #ex=0)
# Rule S.01.01_114: Correctly parsed (#co=0, #ex=0)
# Rule S.01.01_115: Correctly parsed (#co=0, #ex=0)
# Rule S.01.02_102: Correctly parsed (#co=0, #ex=1)
# Rule S.01.02_103: Correctly parsed (#co=0, #ex=1)
# Rule S.01.02_104: Correctly parsed (#co=0, #ex=1)
# Rule S.01.02_105: Correctly parsed (#co=0, #ex=1)
# Rule S.01.02_110: Correctly parsed (#co=0, #ex=1)
# Rule S.01.02_111: Correctly parsed (#co=0, #ex=1)
# Rule S.01.02_112: Correctly parsed (#co=0, #ex=1)
# Rule S.01.03_100: Complex expression
# Rule S.01.03_101: Correctly parsed (#co=1, #ex=0)
# Rule S.01.03_102: Complex expression
# Rule S.01.03_103: Correctly parsed (#co=1, #ex=0)
# Rule S.01.03_104: Complex expression
# Rule S.01.03_105: Correctly parsed (#co=1, #ex=0)
# Rule S.01.03_106: Complex expression
# Rule S.01.03_107: Correctly parsed (#co=1, #ex=0)
# Rule S.01.03_108: Complex expression
# Rule S.01.03_109: Correctly parsed (#co=1, #ex=0)
# Rule S.01.03_110: Complex expression
# Rule S.01.03_111: Complex expression
# Rule S.01.03_112: Correctly parsed (#co=1, #ex=0)
# Rule S.01.03_113: Complex expression
# Rule S.01.03_114: Correctly parsed (#co=1, #ex=0)
# Rule S.02.01_105: Complex expression
# Rule S.02.01_106: Complex expression
# Rule S.02.01_109: Parse error: df[(df['S.02.01.01.01,r0180,c0010']>0) & ((((((df['S.01.01.01.01,r0150,c0010']=='REP) | (TED')) | (df['S.01.01.01.01,r0150,c0010'])=='NOT DUE ANNUALLY AS REP) | (TED F)) | (QUARTER 4')))]
# Rule S.02.01_110: Parse error: df[(df['S.02.01.01.01,r0180,c0010']>0) & ((((((df['S.01.01.04.01,r0150,c0010']=='REP) | (TED')) | (df['S.01.01.04.01,r0150,c0010'])=='NOT DUE ANNUALLY AS REP) | (TED F)) | (QUARTER 4')))]
# Rule S.02.01_115: Correctly parsed (#co=1, #ex=0)
# Rule S.02.01_116: Correctly parsed (#co=1, #ex=0)
# Rule S.03.02_001: Correctly parsed (#co=1, #ex=0)
# Rule S.03.02_002: Correctly parsed (#co=1, #ex=0)
# Rule S.03.02_003: Correctly parsed (#co=1, #ex=0)
# Rule S.03.02_004: Correctly parsed (#co=1, #ex=0)
# Rule S.03.02_005: Correctly parsed (#co=1, #ex=0)
# Rule S.03.02_006: Correctly parsed (#co=0, #ex=0)
# Rule S.03.02_007: Correctly parsed (#co=0, #ex=0)
# Rule S.03.03_100: Correctly parsed (#co=1, #ex=0)
# Rule S.03.03_101: Correctly parsed (#co=1, #ex=0)
# Rule S.03.03_102: Correctly parsed (#co=1, #ex=0)
# Rule S.03.03_103: Correctly parsed (#co=1, #ex=0)
# Rule S.03.03_104: Correctly parsed (#co=1, #ex=0)
# Rule S.03.03_105: Correctly parsed (#co=0, #ex=0)
# Rule S.03.03_106: Correctly parsed (#co=0, #ex=0)
# Rule S.05.01_104: Complex expression
# Rule S.05.01_105: Complex expression
# Rule S.05.01_107: Correctly parsed (#co=0, #ex=0)
# Rule S.05.01_111: Correctly parsed (#co=0, #ex=0)
# Rule S.05.01_112: Correctly parsed (#co=0, #ex=0)
# Rule S.05.01_113: Complex expression
# Rule S.06.01_100: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_101: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_102: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_103: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_104: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_105: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_106: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_107: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_108: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_109: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_110: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_111: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_112: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_113: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_114: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_115: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_116: Correctly parsed (#co=0, #ex=0)
# Rule S.06.01_117: Correctly parsed (#co=0, #ex=0)
# Rule S.06.03_100: Correctly parsed (#co=1, #ex=0)
# Rule S.06.03_101: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_101: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_102: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_103: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_104: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_105: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_106: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_107: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_108: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_109: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_110: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_111: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_112: Parse error: df[(((df['S.07.01.01.01,c0140']=='COLLATERALISATION PERF) | (MED ON A P)) | (TFOLIO BASIS')) & (df['S.07.01.01.01,c0130']>0)]
# Rule S.07.01_113: Parse error: df[(((df['S.07.01.04.01,c0140']=='COLLATERALISATION PERF) | (MED ON A P)) | (TFOLIO BASIS')) & (df['S.07.01.04.01,c0130']>0)]
# Rule S.07.01_114: Correctly parsed (#co=0, #ex=0)
# Rule S.07.01_115: Correctly parsed (#co=0, #ex=0)
# Rule S.07.01_116: Correctly parsed (#co=1, #ex=0)
# Rule S.07.01_117: Correctly parsed (#co=1, #ex=0)
# Rule S.09.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.09.01_101: Correctly parsed (#co=1, #ex=0)
# Rule S.09.01_102: Correctly parsed (#co=1, #ex=0)
# Rule S.09.01_103: Correctly parsed (#co=1, #ex=0)
# Rule S.09.01_104: Correctly parsed (#co=1, #ex=0)
# Rule S.09.01_105: Correctly parsed (#co=1, #ex=0)
# Rule S.10.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.10.01_101: Correctly parsed (#co=1, #ex=0)
# Rule S.10.01_102: Correctly parsed (#co=1, #ex=0)
# Rule S.10.01_103: Complex expression
# Rule S.10.01_104: Correctly parsed (#co=1, #ex=0)
# Rule S.10.01_105: Complex expression
# Rule S.10.01_106: Complex expression
# Rule S.10.01_107: Correctly parsed (#co=1, #ex=0)
# Rule S.10.01_108: Complex expression
# Rule S.10.01_109: Correctly parsed (#co=1, #ex=0)
# Rule S.10.01_110: Complex expression
# Rule S.10.01_111: Correctly parsed (#co=1, #ex=0)
# Rule S.10.01_112: Complex expression
# Rule S.10.01_113: Correctly parsed (#co=0, #ex=1)
# Rule S.10.01_114: Complex expression
# Rule S.10.01_115: Complex expression
# Rule S.12.01_101: Complex expression
# Rule S.12.01_102: Correctly parsed (#co=0, #ex=0)
# Rule S.12.01_103: Correctly parsed (#co=0, #ex=0)
# Rule S.12.01_104: Correctly parsed (#co=0, #ex=0)
# Rule S.12.01_109: Complex expression
# Rule S.12.01_112: Correctly parsed (#co=0, #ex=0)
# Rule S.12.01_116: Correctly parsed (#co=0, #ex=0)
# Rule S.12.01_118: Correctly parsed (#co=0, #ex=0)
# Rule S.14.01_115: Complex expression
# Rule S.14.01_116: Complex expression
# Rule S.15.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.15.01_101: Complex expression
# Rule S.15.01_102: Correctly parsed (#co=1, #ex=0)
# Rule S.15.01_104: Correctly parsed (#co=1, #ex=0)
# Rule S.15.01_105: Complex expression
# Rule S.15.01_106: Parse error: df[(df['S.15.01.04.01,c0040']!=' ') & (df['S.15.01.04.01,c0070']>0)]
# Rule S.15.01_107: Complex expression
# Rule S.15.01_108: Correctly parsed (#co=0, #ex=1)
# Rule S.15.01_109: Complex expression
# Rule S.15.01_110: Correctly parsed (#co=1, #ex=0)
# Rule S.15.01_111: Complex expression
# Rule S.15.01_113: Correctly parsed (#co=0, #ex=1)
# Rule S.15.01_114: Complex expression
# Rule S.15.01_115: Correctly parsed (#co=1, #ex=0)
# Rule S.17.01_118: Complex expression
# Rule S.17.01_119: Complex expression
# Rule S.23.01_108: Complex expression
# Rule S.23.01_111: Complex expression
# Rule S.23.01_113: Complex expression
# Rule S.23.01_114: Complex expression
# Rule S.23.01_131: Correctly parsed (#co=1, #ex=0)
# Rule S.23.01_132: Correctly parsed (#co=0, #ex=1)
# Rule S.23.01_134: Correctly parsed (#co=1, #ex=0)
# Rule S.23.03_104: Complex expression
# Rule S.23.03_105: Complex expression
# Rule S.23.04_100: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_101: Correctly parsed (#co=0, #ex=1)
# Rule S.23.04_102: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_103: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_104: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_105: Complex expression
# Rule S.23.04_106: Complex expression
# Rule S.23.04_107: Complex expression
# Rule S.23.04_108: Complex expression
# Rule S.23.04_109: Complex expression
# Rule S.23.04_110: Complex expression
# Rule S.23.04_111: Complex expression
# Rule S.23.04_112: Complex expression
# Rule S.23.04_113: Correctly parsed (#co=0, #ex=0)
# Rule S.23.04_114: Correctly parsed (#co=0, #ex=0)
# Rule S.23.04_115: Correctly parsed (#co=0, #ex=0)
# Rule S.23.04_116: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_117: Correctly parsed (#co=0, #ex=1)
# Rule S.23.04_118: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_119: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_120: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_121: Parse error: df[(df['S.23.04.01.03,c0265']!=' ') & (df['S.23.04.01.03,c0350']>0)]
# Rule S.23.04_122: Parse error: df[(df['S.23.04.01.03,c0265']!=' ') & (df['S.23.04.01.03,c0360']>0)]
# Rule S.23.04_123: Correctly parsed (#co=0, #ex=0)
# Rule S.23.04_124: Correctly parsed (#co=0, #ex=0)
# Rule S.23.04_125: Correctly parsed (#co=0, #ex=0)
# Rule S.23.04_126: Correctly parsed (#co=0, #ex=0)
# Rule S.23.04_127: Parse error: df[(df['S.23.04.04.03,c0280']>0) & (df['S.23.04.04.03,c0350']>0)]
# Rule S.23.04_128: Parse error: df[(df['S.23.04.04.03,c0280']>0) & (df['S.23.04.04.03,c0360']>0)]
# Rule S.23.04_129: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_130: Correctly parsed (#co=0, #ex=1)
# Rule S.23.04_131: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_132: Correctly parsed (#co=0, #ex=1)
# Rule S.23.04_133: Correctly parsed (#co=0, #ex=1)
# Rule S.23.04_134: Correctly parsed (#co=0, #ex=0)
# Rule S.23.04_135: Correctly parsed (#co=0, #ex=0)
# Rule S.23.04_136: Correctly parsed (#co=0, #ex=0)
# Rule S.23.04_137: Parse error: df[(df['S.23.04.04.04,c0460']>0) & (df['S.23.04.04.04,c0510']>0)]
# Rule S.23.04_138: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_139: Correctly parsed (#co=0, #ex=1)
# Rule S.23.04_140: Correctly parsed (#co=0, #ex=0)
# Rule S.23.04_141: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_142: Correctly parsed (#co=0, #ex=1)
# Rule S.23.04_143: Correctly parsed (#co=1, #ex=0)
# Rule S.23.04_144: Parse error: df[(df['S.23.04.01.06,c0585']!=' ') & (df['S.23.04.01.06,c0620']>0)]
# Rule S.23.04_145: Parse error: df[(df['S.23.04.01.06,c0585']!=' ') & (df['S.23.04.01.06,c0630']>0)]
# Rule S.23.04_146: Complex expression
# Rule S.23.04_147: Complex expression
# Rule S.23.04_148: Complex expression
# Rule S.23.04_149: Complex expression
# Rule S.24.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_101: Correctly parsed (#co=0, #ex=1)
# Rule S.24.01_102: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_103: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_104: Correctly parsed (#co=0, #ex=1)
# Rule S.24.01_105: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_106: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_107: Complex expression
# Rule S.24.01_108: Complex expression
# Rule S.24.01_109: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_110: Correctly parsed (#co=0, #ex=1)
# Rule S.24.01_111: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_112: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_113: Correctly parsed (#co=0, #ex=1)
# Rule S.24.01_114: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_115: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_117: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_118: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_119: Correctly parsed (#co=0, #ex=1)
# Rule S.24.01_120: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_121: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_122: Correctly parsed (#co=0, #ex=1)
# Rule S.24.01_123: Correctly parsed (#co=1, #ex=0)
# Rule S.24.01_124: Complex expression
# Rule S.24.01_126: Correctly parsed (#co=1, #ex=0)
# Rule S.25.01_100: Complex expression
# Rule S.25.01_101: Complex expression
# Rule S.25.01_102: Correctly parsed (#co=1, #ex=0)
# Rule S.25.01_103: Complex expression
# Rule S.25.01_104: Correctly parsed (#co=1, #ex=0)
# Rule S.25.01_105: Complex expression
# Rule S.25.01_106: Correctly parsed (#co=1, #ex=0)
# Rule S.25.01_107: Complex expression
# Rule S.25.01_108: Correctly parsed (#co=1, #ex=0)
# Rule S.25.01_109: Complex expression
# Rule S.25.02_100: Correctly parsed (#co=1, #ex=0)
# Rule S.25.02_102: Correctly parsed (#co=1, #ex=0)
# Rule S.25.02_103: Correctly parsed (#co=1, #ex=0)
# Rule S.25.02_106: Complex expression
# Rule S.25.02_107: Complex expression
# Rule S.25.02_108: Correctly parsed (#co=1, #ex=0)
# Rule S.25.02_109: Correctly parsed (#co=1, #ex=0)
# Rule S.25.02_112: Correctly parsed (#co=1, #ex=0)
# Rule S.25.02_113: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_136: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_137: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_138: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_139: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_140: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_141: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_142: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_143: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_144: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_145: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_146: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_147: Correctly parsed (#co=1, #ex=0)
# Rule S.26.01_148: Complex expression
# Rule S.26.01_149: Complex expression
# Rule S.26.01_150: Complex expression
# Rule S.26.01_151: Complex expression
# Rule S.26.02_100: Correctly parsed (#co=1, #ex=0)
# Rule S.26.02_101: Correctly parsed (#co=1, #ex=0)
# Rule S.26.02_102: Correctly parsed (#co=0, #ex=0)
# Rule S.26.02_103: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_100: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_101: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_102: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_103: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_104: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_105: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_106: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_107: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_108: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_109: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_110: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_111: Correctly parsed (#co=0, #ex=0)
# Rule S.26.03_112: Complex expression
# Rule S.26.03_113: Complex expression
# Rule S.26.04_100: Correctly parsed (#co=0, #ex=0)
# Rule S.26.04_101: Correctly parsed (#co=0, #ex=0)
# Rule S.26.04_102: Correctly parsed (#co=0, #ex=0)
# Rule S.26.04_103: Correctly parsed (#co=0, #ex=0)
# Rule S.26.04_104: Correctly parsed (#co=0, #ex=0)
# Rule S.26.04_105: Correctly parsed (#co=0, #ex=0)
# Rule S.26.04_106: Correctly parsed (#co=0, #ex=0)
# Rule S.26.04_107: Correctly parsed (#co=0, #ex=0)
# Rule S.26.04_108: Correctly parsed (#co=1, #ex=0)
# Rule S.26.04_109: Correctly parsed (#co=1, #ex=0)
# Rule S.26.04_110: Correctly parsed (#co=1, #ex=0)
# Rule S.26.04_111: Correctly parsed (#co=1, #ex=0)
# Rule S.26.04_116: Correctly parsed (#co=0, #ex=0)
# Rule S.26.04_117: Correctly parsed (#co=1, #ex=0)
# Rule S.26.04_118: Correctly parsed (#co=1, #ex=0)
# Rule S.26.04_119: Correctly parsed (#co=0, #ex=0)
# Rule S.26.04_120: Correctly parsed (#co=1, #ex=0)
# Rule S.26.04_121: Correctly parsed (#co=1, #ex=0)
# Rule S.26.05_112: Correctly parsed (#co=0, #ex=1)
# Rule S.26.05_113: Correctly parsed (#co=0, #ex=1)
# Rule S.26.06_101: Correctly parsed (#co=1, #ex=0)
# Rule S.26.06_102: Correctly parsed (#co=1, #ex=0)
# Rule S.26.06_103: Correctly parsed (#co=1, #ex=0)
# Rule S.26.06_104: Correctly parsed (#co=1, #ex=0)
# Rule S.26.06_105: Parse error: df[(df['S.26.06.01.01,r0340,c0020']!=0) & (df['S.26.06.01.01,r0340,c0020']==MIN((df['S.26.06.01.01,r0310,c0020'],df['S.26.06.01.01,r0320,c0020'])+0.25*df['S.26.06.01.01,r0330,c0020']))]
# Rule S.26.06_106: Parse error: df[(df['S.26.06.04.01,r0340,c0020']!=0) & (df['S.26.06.04.01,r0340,c0020']==MIN((df['S.26.06.04.01,r0310,c0020'],df['S.26.06.04.01,r0320,c0020'])+0.25*df['S.26.06.04.01,r0330,c0020']))]
# Rule S.27.01_110: Complex expression
# Rule S.27.01_111: Complex expression
# Rule S.27.01_112: Complex expression
# Rule S.27.01_113: Complex expression
# Rule S.27.01_162: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_163: Complex expression
# Rule S.27.01_164: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_165: Complex expression
# Rule S.27.01_166: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_167: Complex expression
# Rule S.27.01_168: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_169: Complex expression
# Rule S.27.01_170: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_171: Complex expression
# Rule S.27.01_172: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_173: Complex expression
# Rule S.27.01_174: Complex expression
# Rule S.27.01_175: Complex expression
# Rule S.27.01_176: Complex expression
# Rule S.27.01_177: Complex expression
# Rule S.27.01_178: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_179: Complex expression
# Rule S.27.01_180: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_181: Complex expression
# Rule S.27.01_182: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_183: Complex expression
# Rule S.27.01_184: Complex expression
# Rule S.27.01_185: Complex expression
# Rule S.27.01_186: Complex expression
# Rule S.27.01_187: Complex expression
# Rule S.27.01_188: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_189: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_190: Complex expression
# Rule S.27.01_191: Complex expression
# Rule S.27.01_192: Complex expression
# Rule S.27.01_193: Complex expression
# Rule S.27.01_194: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_195: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_196: Complex expression
# Rule S.27.01_197: Complex expression
# Rule S.27.01_198: Complex expression
# Rule S.27.01_199: Complex expression
# Rule S.27.01_200: Complex expression
# Rule S.27.01_201: Complex expression
# Rule S.27.01_202: Complex expression
# Rule S.27.01_203: Complex expression
# Rule S.27.01_204: Complex expression
# Rule S.27.01_205: Complex expression
# Rule S.27.01_206: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_207: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_208: Complex expression
# Rule S.27.01_209: Complex expression
# Rule S.27.01_210: Parse error: df[(df['S.27.01.01.04,r1590,c0210']==SUM(r1410,c0210,r1580,c0210))]
# Rule S.27.01_211: Parse error: df[(df['S.27.01.04.04,r1590,c0210']==SUM(r1410,c0210,r1580,c0210))]
# Rule S.27.01_212: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_213: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_214: Complex expression
# Rule S.27.01_215: Complex expression
# Rule S.27.01_216: Complex expression
# Rule S.27.01_217: Complex expression
# Rule S.27.01_218: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_219: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_220: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_221: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_224: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_225: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_226: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_227: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_228: Complex expression
# Rule S.27.01_229: Complex expression
# Rule S.27.01_230: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_231: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_232: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_233: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_234: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_235: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_236: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_237: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_238: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_239: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_240: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_241: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_242: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_243: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_244: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_245: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_246: Complex expression
# Rule S.27.01_247: Complex expression
# Rule S.27.01_248: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_249: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_250: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_251: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_252: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_253: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_254: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_255: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_256: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_257: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_258: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_259: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_260: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_261: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_262: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_263: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_264: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_265: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_266: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_267: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_268: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_269: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_270: Complex expression
# Rule S.27.01_271: Complex expression
# Rule S.27.01_276: Complex expression
# Rule S.27.01_277: Complex expression
# Rule S.27.01_278: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_279: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_280: Complex expression
# Rule S.27.01_281: Complex expression
# Rule S.27.01_282: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_283: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_284: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_285: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_286: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_287: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_288: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_289: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_290: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_291: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_292: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_293: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_294: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_295: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_296: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_297: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_298: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_299: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_300: Complex expression
# Rule S.27.01_301: Complex expression
# Rule S.27.01_302: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_303: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_304: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_305: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_306: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_307: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_308: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_309: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_310: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_311: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_312: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_313: Correctly parsed (#co=1, #ex=0)
# Rule S.27.01_314: Correctly parsed (#co=0, #ex=0)
# Rule S.27.01_315: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.28.01_101: Correctly parsed (#co=1, #ex=0)
# Rule S.28.01_103: Correctly parsed (#co=1, #ex=0)
# Rule S.28.01_104: Correctly parsed (#co=1, #ex=0)
# Rule S.28.01_105: Correctly parsed (#co=1, #ex=0)
# Rule S.28.01_106: Correctly parsed (#co=0, #ex=1)
# Rule S.28.01_107: Correctly parsed (#co=0, #ex=1)
# Rule S.28.01_108: Correctly parsed (#co=0, #ex=1)
# Rule S.28.01_109: Correctly parsed (#co=1, #ex=0)
# Rule S.28.01_110: Correctly parsed (#co=1, #ex=0)
# Rule S.28.01_111: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_112: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_113: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_114: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_115: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_116: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_117: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_118: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_119: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_120: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_121: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_122: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_123: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_124: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_125: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_126: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_127: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_128: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_130: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_131: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_132: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_133: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_134: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_135: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_136: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_137: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_138: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_139: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_140: Correctly parsed (#co=0, #ex=0)
# Rule S.28.01_141: Correctly parsed (#co=0, #ex=0)
# Rule S.29.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.30.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.30.01_101: Correctly parsed (#co=0, #ex=0)
# Rule S.30.01_102: Correctly parsed (#co=0, #ex=0)
# Rule S.30.01_103: Correctly parsed (#co=0, #ex=0)
# Rule S.30.01_105: Parse error: df[((df['S.30.01.01.01,c0050']=='OTHER THAN NON-TRADITIONAL) | (FINITE RE')) & (df['S.30.01.01.01,c0100']>0)]
# Rule S.30.01_106: Parse error: df[((df['S.30.01.01.01,c0050']=='OTHER THAN NON-TRADITIONAL) | (FINITE RE')) & (df['S.30.01.01.01,c0110']>0)]
# Rule S.30.01_107: Correctly parsed (#co=0, #ex=0)
# Rule S.30.01_108: Correctly parsed (#co=0, #ex=0)
# Rule S.30.01_109: Correctly parsed (#co=0, #ex=0)
# Rule S.30.01_110: Correctly parsed (#co=0, #ex=0)
# Rule S.30.01_111: Correctly parsed (#co=0, #ex=0)
# Rule S.30.01_112: Correctly parsed (#co=0, #ex=0)
# Rule S.30.01_113: Correctly parsed (#co=0, #ex=0)
# Rule S.30.01_114: Correctly parsed (#co=1, #ex=0)
# Rule S.30.01_115: Correctly parsed (#co=1, #ex=0)
# Rule S.30.01_116: Correctly parsed (#co=1, #ex=0)
# Rule S.30.01_117: Parse error: df[(df['S.30.01.01.02,c0200']!=' ') & (df['S.30.01.01.02,c0260']>0)]
# Rule S.30.01_118: Parse error: df[(df['S.30.01.01.02,c0200']!=' ') & (df['S.30.01.01.02,c0270']>0)]
# Rule S.30.01_119: Correctly parsed (#co=1, #ex=0)
# Rule S.30.01_120: Correctly parsed (#co=0, #ex=1)
# Rule S.30.01_121: Correctly parsed (#co=0, #ex=1)
# Rule S.30.02_100: Correctly parsed (#co=0, #ex=1)
# Rule S.30.02_101: Correctly parsed (#co=1, #ex=0)
# Rule S.30.02_102: Correctly parsed (#co=0, #ex=1)
# Rule S.30.02_103: Correctly parsed (#co=0, #ex=1)
# Rule S.30.02_104: Correctly parsed (#co=1, #ex=0)
# Rule S.30.02_105: Correctly parsed (#co=0, #ex=1)
# Rule S.30.02_106: Correctly parsed (#co=1, #ex=0)
# Rule S.30.02_107: Correctly parsed (#co=1, #ex=0)
# Rule S.30.02_109: Correctly parsed (#co=1, #ex=0)
# Rule S.30.02_110: Correctly parsed (#co=1, #ex=0)
# Rule S.30.02_111: Correctly parsed (#co=1, #ex=0)
# Rule S.30.03_101: Correctly parsed (#co=0, #ex=0)
# Rule S.30.03_102: Parse error: df[((df['S.30.03.01.01,c0060']=='OTHER THAN NON-TRADITIONAL) | (FINITE RE')) & (df['S.30.03.01.01,c0110']>0)]
# Rule S.30.03_103: Parse error: df[((df['S.30.03.01.01,c0060']=='OTHER THAN NON-TRADITIONAL) | (FINITE RE')) & (df['S.30.03.01.01,c0120']>0)]
# Rule S.30.03_104: Correctly parsed (#co=0, #ex=0)
# Rule S.30.03_105: Correctly parsed (#co=0, #ex=0)
# Rule S.30.03_106: Correctly parsed (#co=0, #ex=0)
# Rule S.30.04_100: Correctly parsed (#co=1, #ex=0)
# Rule S.30.04_101: Correctly parsed (#co=1, #ex=0)
# Rule S.30.04_103: Correctly parsed (#co=1, #ex=0)
# Rule S.30.04_104: Correctly parsed (#co=1, #ex=0)
# Rule S.30.04_105: Correctly parsed (#co=1, #ex=0)
# Rule S.30.04_107: Correctly parsed (#co=1, #ex=0)
# Rule S.30.04_108: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_101: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_102: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_103: Correctly parsed (#co=0, #ex=1)
# Rule S.31.01_105: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_106: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_107: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_108: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_111: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_112: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_113: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_114: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_115: Correctly parsed (#co=1, #ex=0)
# Rule S.31.01_116: Correctly parsed (#co=1, #ex=0)
# Rule S.32.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.32.01_101: Correctly parsed (#co=1, #ex=0)
# Rule S.32.01_102: Correctly parsed (#co=1, #ex=0)
# Rule S.32.01_103: Correctly parsed (#co=1, #ex=0)
# Rule S.32.01_104: Correctly parsed (#co=1, #ex=0)
# Rule S.32.01_105: Correctly parsed (#co=0, #ex=0)
# Rule S.32.01_106: Correctly parsed (#co=0, #ex=1)
# Rule S.32.01_107: Correctly parsed (#co=0, #ex=0)
# Rule S.32.01_108: Correctly parsed (#co=1, #ex=0)
# Rule S.32.01_109: Correctly parsed (#co=1, #ex=0)
# Rule S.32.01_110: Correctly parsed (#co=0, #ex=1)
# Rule S.32.01_111: Correctly parsed (#co=1, #ex=0)
# Rule S.32.01_112: Correctly parsed (#co=1, #ex=0)
# Rule S.32.01_113: Correctly parsed (#co=0, #ex=0)
# Rule S.34.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.34.01_101: Correctly parsed (#co=1, #ex=0)
# Rule S.34.01_102: Correctly parsed (#co=1, #ex=0)
# Rule S.34.01_103: Correctly parsed (#co=0, #ex=1)
# Rule S.34.01_104: Correctly parsed (#co=0, #ex=1)
# Rule S.35.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.35.01_101: Correctly parsed (#co=0, #ex=1)
# Rule S.35.01_102: Correctly parsed (#co=0, #ex=1)
# Rule S.35.01_103: Correctly parsed (#co=0, #ex=1)
# Rule S.35.01_104: Correctly parsed (#co=0, #ex=1)
# Rule S.35.01_105: Correctly parsed (#co=0, #ex=1)
# Rule S.35.01_106: Correctly parsed (#co=0, #ex=1)
# Rule S.35.01_107: Correctly parsed (#co=0, #ex=1)
# Rule S.35.01_108: Correctly parsed (#co=0, #ex=1)
# Rule S.36.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.36.01_102: Correctly parsed (#co=1, #ex=0)
# Rule S.36.01_104: Correctly parsed (#co=1, #ex=0)
# Rule S.36.01_106: Parse error: df[(df['S.36.01.01.01,c0010']!=' ') & (df['S.36.01.01.01,c0110']>0)]
# Rule S.36.01_108: Correctly parsed (#co=1, #ex=0)
# Rule S.36.02_100: Correctly parsed (#co=1, #ex=0)
# Rule S.36.02_102: Correctly parsed (#co=1, #ex=0)
# Rule S.36.02_104: Correctly parsed (#co=1, #ex=0)
# Rule S.36.02_106: Parse error: df[(df['S.36.02.01.01,c0010']!=' ') & (df['S.36.02.01.01,c0110']>0)]
# Rule S.36.02_108: Parse error: df[(df['S.36.02.01.01,c0010']!=' ') & (df['S.36.02.01.01,c0120']>0)]
# Rule S.36.02_110: Correctly parsed (#co=1, #ex=0)
# Rule S.36.02_112: Correctly parsed (#co=1, #ex=0)
# Rule S.36.02_115: Correctly parsed (#co=1, #ex=0)
# Rule S.36.03_100: Correctly parsed (#co=1, #ex=0)
# Rule S.36.03_102: Correctly parsed (#co=1, #ex=0)
# Rule S.36.03_104: Parse error: df[(df['S.36.03.01.01,c0010']!=' ') & (df['S.36.03.01.01,c0080']>0)]
# Rule S.36.03_108: Correctly parsed (#co=1, #ex=0)
# Rule S.36.03_110: Correctly parsed (#co=1, #ex=0)
# Rule S.36.03_113: Correctly parsed (#co=1, #ex=0)
# Rule S.36.03_114: Correctly parsed (#co=1, #ex=0)
# Rule S.36.03_116: Correctly parsed (#co=0, #ex=1)
# Rule S.36.04_100: Correctly parsed (#co=1, #ex=0)
# Rule S.36.04_102: Correctly parsed (#co=1, #ex=0)
# Rule S.36.04_104: Correctly parsed (#co=1, #ex=0)
# Rule S.36.04_106: Correctly parsed (#co=1, #ex=0)
# Rule S.36.04_113: Correctly parsed (#co=1, #ex=0)
# Rule S.37.01_100: Correctly parsed (#co=1, #ex=0)
# Rule S.37.01_101: Correctly parsed (#co=1, #ex=0)
# Rule S.37.01_102: Correctly parsed (#co=1, #ex=0)
# Rule S.37.01_103: Correctly parsed (#co=1, #ex=0)
# Rule S.37.01_104: Correctly parsed (#co=1, #ex=0)
# Rule S.37.01_107: Correctly parsed (#co=1, #ex=0)
# Rule S.37.01_108: Complex expression
# Rule S.37.01_109: Complex expression
# Rule S.37.01_111: Complex expression
# Rule S.37.01_112: Complex expression

# %%
df['S.23.04.04.03,c0350']
# Out:
# 0    text
# Name: S.23.04.04.03,c0350, dtype: object

# %%
df[((df['S.23.04.04.03,c0280'])>(0))&((df['S.23.04.04.03,c0350'])>(0))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-206-86ba050f1657> in <module>
# ----> 1 df[((df['S.23.04.04.03,c0280'])>(0))&((df['S.23.04.04.03,c0350'])>(0))]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'
